# %%
import pandas as pd
df = pd.read_csv("sample_data_01.csv")

# %%
df
# Out:
#     都道府県       総人口   総人口(男)   総人口(女)      日本人口   外国人人口       総面積     可住地面積  \
# 0    北海道   5250000  2472000  2778000   5211000   21676  83456.87  22699.23
# 1    青森県   1246000   585000   661000   1240000    3447   9644.54   3253.19
# 2    岩手県   1227000   592000   635000   1219000    5017  15278.89   3751.37
# 3    宮城県   2306000  1127000  1179000   2283000   13989   7285.76   3185.91
# 4    秋田県    966000   454000   512000    963000    2914  11636.25   3233.34
# 5    山形県   1078000   520000   558000   1070000    5503   9323.46   2873.29
# 6    福島県   1846000   914000   931000   1831000    8725  13782.76   4230.73
# 7    茨城県   2860000  1427000  1433000   2810000   41310   6095.72   3888.84
# 8    栃木県   1934000   964000   970000   1906000   26494   6408.28   3005.06
# 9    群馬県   1942000   962000   981000   1886000   37126   6362.33   2269.02
# 10   埼玉県   7350000  3668000  3682000   7174000  105203   3798.13   2603.09
# ...

# %%
list(df)
# Out:
# ['都道府県',
#  '総人口',
#  '総人口(男)',
#  '総人口(女)',
#  '日本人口',
#  '外国人人口',
#  '総面積',
#  '可住地面積',
#  '県内総生産額',
#  '県民取得',
#  '民営事業所数',
#  '民間事業所従業員数',
#  '小学校数',
#  '中学校数',
#  '高等学校数',
#  '小学校教員数',
#  '中学校教員数',
#  '高等学校教員数',
#  '公民館数',
#  '図書館数',
#  'ＮＰＯ法人認証数',
#  '総住宅数',
#  '空き家数',
#  'コンビニ数',
#  '飲食店数',
#  '公衆浴場数',
#  '一般病院数',
#  '薬局数',
#  '世帯主の配偶者の収入',
#  '消費支出',
#  '住居費',
#  '光熱・水道費',
#  '教育費']

# %%
df.sort_values("総人口",ascending=False).tail()
# Out:
#    都道府県     総人口  総人口(男)  総人口(女)    日本人口  外国人人口      総面積    可住地面積  県内総生産額  \
# 17  福井県  768000  374000  394000  756000   9448  4189.83  1077.28   33236
# 35  徳島県  728000  347000  381000  723000   3871  4146.67  1016.04   31569
# 38  高知県  698000  329000  369000  693000   3236  7105.16  1161.29   24295
# 31  島根県  674000  326000  349000  665000   5371  6707.95  1270.98   24729
# 30  鳥取県  556000  266000  290000  551000   3384  3507.28   904.34   18967
#
#      県民取得  ...  コンビニ数  飲食店数  公衆浴場数  一般病院数  薬局数  世帯主の配偶者の収入    消費支出    住居費  \
# 17  25421  ...    238  4058     18     57  304       90800  290464  12243
# 35  22973  ...    164  3673     24     92  390      120653  309361  14281
# 38  18915  ...    183  4423      9    113  390      120597  297577  19723
# 31  17485  ...    189  3011      2     40  330      150233  322972  18742
# 30  14041  ...    154  2604     15     39  274      117313  324079  17658
#
#     光熱・水道費    教育費
# 17   24883   9089
# 35   21216  10267
# 38   20743   9571
# ...

# %%
df.sort_values("ＮＰＯ法人認証数",ascending=False).tail()
# Out:
#    都道府県     総人口  総人口(男)  総人口(女)    日本人口  外国人人口       総面積    可住地面積  県内総生産額  \
# 4   秋田県  966000  454000  512000  963000   2914  11636.25  3233.34   35630
# 38  高知県  698000  329000  369000  693000   3236   7105.16  1161.29   24295
# 30  鳥取県  556000  266000  290000  551000   3384   3507.28   904.34   18967
# 31  島根県  674000  326000  349000  665000   5371   6707.95  1270.98   24729
# 17  福井県  768000  374000  394000  756000   9448   4189.83  1077.28   33236
#
#      県民取得  ...  コンビニ数  飲食店数  公衆浴場数  一般病院数  薬局数  世帯主の配偶者の収入    消費支出    住居費  \
# 4   26876  ...    309  4704     13     52  521      102944  300312  14661
# 38  18915  ...    183  4423      9    113  390      120597  297577  19723
# 30  14041  ...    154  2604     15     39  274      117313  324079  17658
# 31  17485  ...    189  3011      2     40  330      150233  322972  18742
# 17  25421  ...    238  4058     18     57  304       90800  290464  12243
#
#     光熱・水道費   教育費
# 4    25743  4394
# 38   20743  9571
# 30   21726  5735
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["コンビニ数"],df["県民取得"])
plt.xlabel("C")
plt.ylabel("P")
# Out:
# Text(0, 0.5, 'P')

# %%
import matplotlib.pyplot as plt
plt.scatter(df["ＮＰＯ法人認証数"],df["外国人人口"])
plt.xlabel("N")
plt.ylabel("P")
# Out:
# Text(0, 0.5, 'P')

# %%
from sklearn.linear_model import LinearRegression
X = df[["教育費","外国人人口"]]
y = df["県民取得"]
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
import numpy as np
model.predict(np.array([[20000,200]]))
# Out:
# /Users/kantanakagawa/camp/python/day05/data_science_01/.venv/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([22160.61390058])
